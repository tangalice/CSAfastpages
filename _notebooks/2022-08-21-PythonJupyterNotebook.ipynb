# %% [markdown]
# # "Python Jupyter Notebook"
# > "Python Code in Jupyter Notebook"
#
# - toc: true
# - branch: master
# - badges: true
# - comments: true
# - author: Alice Tang
# - categories: [python, jupyter]

# %%
msg1 = "Hello"
msg2 = "I'm Alice"
print(msg1)
print(msg2)
# Out:
# Hello
# I'm Alice
